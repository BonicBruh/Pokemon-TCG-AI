# %% [markdown]
# # Train the Pokémon TCG PPO agent on Kaggle
# Attach one daily episode dataset as a Notebook input before running the behavior-cloning cell.

# %%
# !git clone https://github.com/BonicBruh/Pokemon-TCG-AI.git
# %cd Pokemon-TCG-AI
# !pip install -q -r requirements-training.txt

# %%
# !python validate_deck.py
# !python smoke_test.py

# %%
EPISODES = '/kaggle/input/YOUR-DAILY-EPISODE-DATASET'
# !python train.py --bc-episodes {EPISODES} --bc-winners-only --bc-max-examples 100000 --num-envs 8 --updates 500 --save-dir models

# %%
# !python evaluate.py --checkpoint models/latest.pt --games 100 --output evaluation.csv
# !python export_submission.py --checkpoint models/latest.pt --output submission.tar.gz
